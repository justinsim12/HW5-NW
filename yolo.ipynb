# %%
from align import NeedlemanWunsch, read_fasta

seq3, _ = read_fasta("./data/test_seq3.fa")
seq4, _ = read_fasta("./data/test_seq4.fa")

nw = NeedlemanWunsch("substitution_matrices/BLOSUM62.mat", gap_open=-10, gap_extend=-1)

print(nw.sub_dict)

score, aligned_seqA, aligned_seqB = nw.align(seq3, seq4)

expected_score = 17
expected_aligned_seqA = 'MAVHQLIRRP'
expected_aligned_seqB = 'M---QLIRHP'

print(nw._align_matrix)
print(nw._gapA_matrix)
print(nw._gapB_matrix)
print(nw._back)

print(score)
print(aligned_seqA)
print(aligned_seqB)
# assert score == expected_score, f"Expected {expected_score}, but got {score}"
# assert aligned_seqA == expected_aligned_seqA, f"Expected {expected_aligned_seqA}, but got {aligned_seqA}"
#assert aligned_seqB == expected_aligned_seqB, f"Expected {expected_aligned_seqB}, but got {aligned_seqB}"

# %%
from align import NeedlemanWunsch, read_fasta

seq3, _ = read_fasta("./data/test_seq1.fa")
seq4, _ = read_fasta("./data/test_seq2.fa")

nw = NeedlemanWunsch("substitution_matrices/BLOSUM62.mat", gap_open=-10, gap_extend=-1)

print(nw.sub_dict)

score, aligned_seqA, aligned_seqB = nw.align(seq3, seq4)

expected_score = 17
expected_aligned_seqA = 'MAVHQLIRRP'
expected_aligned_seqB = 'M---QLIRHP'

print(nw._align_matrix)
print(nw._gapA_matrix)
print(nw._gapB_matrix)
print(nw._back)

print(score)
print(aligned_seqA)
print(aligned_seqB)
# Out:
# {('A', 'A'): 4.0, ('R', 'A'): -1.0, ('N', 'A'): -2.0, ('D', 'A'): -2.0, ('C', 'A'): 0.0, ('Q', 'A'): -1.0, ('E', 'A'): -1.0, ('G', 'A'): 0.0, ('H', 'A'): -2.0, ('I', 'A'): -1.0, ('L', 'A'): -1.0, ('K', 'A'): -1.0, ('M', 'A'): -1.0, ('F', 'A'): -2.0, ('P', 'A'): -1.0, ('S', 'A'): 1.0, ('T', 'A'): 0.0, ('W', 'A'): -3.0, ('Y', 'A'): -2.0, ('V', 'A'): 0.0, ('B', 'A'): -2.0, ('Z', 'A'): -1.0, ('X', 'A'): 0.0, ('*', 'A'): -4.0, ('A', 'R'): -1.0, ('R', 'R'): 5.0, ('N', 'R'): 0.0, ('D', 'R'): -2.0, ('C', 'R'): -3.0, ('Q', 'R'): 1.0, ('E', 'R'): 0.0, ('G', 'R'): -2.0, ('H', 'R'): 0.0, ('I', 'R'): -3.0, ('L', 'R'): -2.0, ('K', 'R'): 2.0, ('M', 'R'): -1.0, ('F', 'R'): -3.0, ('P', 'R'): -2.0, ('S', 'R'): -1.0, ('T', 'R'): -1.0, ('W', 'R'): -3.0, ('Y', 'R'): -2.0, ('V', 'R'): -3.0, ('B', 'R'): -1.0, ('Z', 'R'): 0.0, ('X', 'R'): -1.0, ('*', 'R'): -4.0, ('A', 'N'): -2.0, ('R', 'N'): 0.0
, ('G', 'E'): -2.0, ('H', 'E'): 0.0, ('I', 'E'): -3.0, ('L', 'E'): -3.0, ('K', 'E'): 1.0, ('M', 'E'): -2.0, ('F', 'E'): -3.0, ('P', 'E'): -1.0, ('S', 'E'): 0.0, ('T', 'E'): -1.0, ('W', 'E'): -3.0, ('Y', 'E'): -2.0, ('V', 'E'): -2.0, ('B', 'E'): 1.0, ('Z', 'E'): 4.0, ('X', 'E'): -1.0, ('*', 'E'): -4.0, ('A', 'G'): 0.0, ('R', 'G'): -2.0, ('N', 'G'): 0.0, ('D', 'G'): -1.0, ('C', 'G'): -3.0, ('Q', 'G'): -2.0, ('E', 'G'): -2.0, ('G', 'G'): 6.0, ('H', 'G'): -2.0, ('I', 'G'): -4.0, ('L', 'G'): -4.0, ('K', 'G'): -2.0, ('M', 'G'): -3.0, ('F', 'G'): -3.0, ('P', 'G'): -2.0, ('S', 'G'): 0.0, ('T', 'G'): -2.0, ('W', 'G'): -2.0, ('Y', 'G'): -3.0, ('V', 'G'): -3.0, ('B', 'G'): -1.0, ('Z', 'G'): -2.0, ('X', 'G'): -1.0, ('*', 'G'): -4.0, ('A', 'H'): -2.0, ('R', 'H'): 0.0, ('N', 'H'): 1.0, ('D', 'H'): -1.0, ('C', 'H'): -3.0, ('Q', 'H'): 0.0, ('E', 'H'): 0.0, ('G', 'H'): -2.0, ('H', 'H'): 8.0, ('I', 'H'): -3.0, ('L', 'H'): -3.0, ('K', 'H'): -1.0, ('M', 'H'): -2.0, ('F', 'H'): -1.0, ('P', 'H'): -2.0, ('S', 'H'): -1.0, ('T', 'H'): -2.0, ('W', 'H'): -2.0, ('Y', 'H'): 2.0, ('V', 'H'): -3.0, ('B', 'H'): 0.0, ('Z', 'H'): 0.0, ('X', 'H'): -1.0, ('*', 'H'): -4.0, ('A', 'I'): -1.0, ('R', 'I'): -3.0, ('N', 'I'): -3.0, ('D', 'I'): -3.0, ('C', 'I'): -1.0, ('Q', 'I'): -3.0, ('E', 'I'): -3.0, ('G', 'I'): -4.0, ('H', 'I'): -3.0, ('I', 'I'): 4.0,  ...
# [[  0. -10. -11. -12.]
#  [-10.   5.  -6.  -7.]
#  [-11.  -6.   4.  -7.]
#  [-12.  -7.  -1.   5.]
#  [-13.  -8.  -6.   4.]]
# [[-inf -inf -inf -inf]
#  [-10. -21. -22. -23.]
#  [-11.  -6. -17. -18.]
#  [-12.  -7.  -7. -18.]
#  [-13.  -8.  -8.  -6.]]
# [[-inf -10. -11. -12.]
#  [-inf -21.  -6.  -7.]
#  [-inf -22. -17.  -7.]
#  [-inf -23. -18. -12.]
#  [-inf -24. -19. -17.]]
# [['' 'L' 'L' 'L']
#  ['U' 'D' 'L' 'L']
#  ['U' 'U' 'D' 'L']
#  ['U' 'U' 'D' 'D']
#  ['U' 'U' 'D' 'D']]
# 4.0
# MYQR
# M-QR
